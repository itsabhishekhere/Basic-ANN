# %%
#importing funtions
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing dataset
dataset=pd.read_csv("Churn_Modelling.csv")
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
#defining features and  targeted Values
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
# #encoding categorical data
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.compose import ColumnTransformer
# columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(), [1,6])], remainder='passthrough')
# X = np.array(columnTransformer.fit_transform(X), dtype = np.str)
# X
# try coding this way

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]
# Out:
# C:\Users\abhis\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhis\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Part - 2 : Making the ANN!

# %%
# Importing the keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Initializing the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(6, kernel_initializer="uniform", activation = 'relu', input_dim = 11))

# %%
# Adding the input layer and the second hidden layer
classifier.add(Dense(6, kernel_initializer="uniform", activation = 'relu'))

# %%
# Adding the output layer
classifier.add(Dense(1, kernel_initializer="uniform", activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fiting the ANN to the training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 3s 428us/step - loss: 0.4878 - accuracy: 0.7968
# Epoch 2/100
# 8000/8000 [==============================] - 3s 321us/step - loss: 0.4203 - accuracy: 0.8205
# Epoch 3/100
# 8000/8000 [==============================] - 3s 332us/step - loss: 0.4133 - accuracy: 0.8275
# Epoch 4/100
# 8000/8000 [==============================] - 3s 337us/step - loss: 0.4086 - accuracy: 0.8309
# Epoch 5/100
# 8000/8000 [==============================] - 2s 285us/step - loss: 0.4058 - accuracy: 0.8321
# Epoch 6/100
# 8000/8000 [==============================] - 3s 329us/step - loss: 0.4032 - accuracy: 0.8331
# Epoch 7/100
# 8000/8000 [==============================] - ETA: 0s - loss: 0.4030 - accuracy: 0.83 - 4s 484us/step - loss: 0.4028 - accuracy: 0.8316
# Epoch 8/100
# 8000/8000 [==============================] - 4s 519us/step - loss: 0.4020 - accuracy: 0.8336
# Epoch 9/100
# 8000/8000 [==============================] - 4s 531us/step - loss: 0.4010 - accuracy: 0.8332
# Epoch 10/100
# 8000/8000 [==============================] - 4s 506us/step - loss: 0.4000 - accuracy: 0.8355
# Epoch 11/100
# 8000/8000 [==============================] - 3s 334us/step - loss: 0.3999 - accuracy: 0.8354
# Epoch 12/100
# 8000/8000 [==============================] - 3s 349us/step - loss: 0.3991 - accuracy: 0.8346
# Epoch 13/100
# 8000/8000 [==============================] - 3s 365us/step - loss: 0.3984 - accuracy: 0.83490s - loss: 0.3990 - accu
# Epoch 14/100
# 8000/8000 [==============================] - 3s 359us/step - loss: 0.3982 - accuracy: 0.8355
# Epoch 15/100
# 8000/8000 [==============================] - 3s 390us/step - loss: 0.3974 - accuracy: 0.8361
# Epoch 16/100
# 8000/8000 [==============================] - 3s 318us/step - loss: 0.3976 - accuracy: 0.8364
# Epoch 17/100
# 8000/8000 [==============================] - 4s 471us/step - loss: 0.3971 - accuracy: 0.8338
# Epoch 18/100
# 8000/8000 [==============================] - 4s 510us/step - loss: 0.3970 - accuracy: 0.8361
# Epoch 19/100
# 8000/8000 [==============================] - 3s 352us/step - loss: 0.3966 - accuracy: 0.8345
# Epoch 20/100
# 8000/8000 [==============================] - 3s 353us/step - loss: 0.3961 - accuracy: 0.8364
# Epoch 21/100
# 8000/8000 [==============================] - 3s 342us/step - loss: 0.3955 - accuracy: 0.8349
# Epoch 22/100
# 8000/8000 [==============================] - 4s 492us/step - loss: 0.3950 - accuracy: 0.8346
# Epoch 23/100
# 8000/8000 [==============================] - 5s 565us/step - loss: 0.3953 - accuracy: 0.8365
# Epoch 24/100
# 8000/8000 [==============================] - 4s 562us/step - loss: 0.3948 - accuracy: 0.8341
# Epoch 25/100
# 8000/8000 [==============================] - 4s 517us/step - loss: 0.3952 - accuracy: 0.8344
# Epoch 26/100
# 8000/8000 [==============================] - 4s 511us/step - loss: 0.3943 - accuracy: 0.8357
# Epoch 27/100
# 8000/8000 [==============================] - 4s 477us/step - loss: 0.3945 - accuracy: 0.83591s - loss:
# Epoch 28/100
# 8000/8000 [==============================] - 2s 312us/step - loss: 0.3943 - accuracy: 0.8338
# Epoch 29/100
# 8000/8000 [==============================] - 2s 303us/step - loss: 0.3942 - accuracy: 0.8342
# Epoch 30/100
# 8000/8000 [==============================] - 2s 307us/step - loss: 0.3939 - accuracy: 0.8367
# Epoch 31/100
# 8000/8000 [==============================] - 4s 523us/step - loss: 0.3941 - accuracy: 0.8346
# Epoch 32/100
# 8000/8000 [==============================] - 4s 485us/step - loss: 0.3940 - accuracy: 0.8361
# Epoch 33/100
# 8000/8000 [==============================] - 3s 385us/step - loss: 0.3935 - accuracy: 0.8354
# Epoch 34/100
# 8000/8000 [==============================] - 3s 336us/step - loss: 0.3940 - accuracy: 0.8356
# Epoch 35/100
# 8000/8000 [==============================] - 2s 302us/step - loss: 0.3933 - accuracy: 0.8353
# Epoch 36/100
# 8000/8000 [==============================] - 2s 302us/step - loss: 0.3933 - accuracy: 0.8345
# Epoch 37/100
# 8000/8000 [==============================] - 3s 433us/step - loss: 0.3929 - accuracy: 0.8363
# Epoch 38/100
# 8000/8000 [==============================] - 2s 284us/step - loss: 0.3929 - accuracy: 0.8354
# Epoch 39/100
# 8000/8000 [==============================] - 1s 177us/step - loss: 0.3925 - accuracy: 0.8354
# Epoch 40/100
# 8000/8000 [==============================] - 2s 191us/step - loss: 0.3930 - accuracy: 0.8367
# Epoch 41/100
# 8000/8000 [==============================] - 1s 185us/step - loss: 0.3926 - accuracy: 0.8350
# Epoch 42/100
# 8000/8000 [==============================] - 1s 186us/step - loss: 0.3924 - accuracy: 0.8366
# Epoch 43/100
# 8000/8000 [==============================] - 2s 189us/step - loss: 0.3922 - accuracy: 0.8370
# Epoch 44/100
# 8000/8000 [==============================] - 1s 175us/step - loss: 0.3912 - accuracy: 0.8378
# Epoch 45/100
# 8000/8000 [==============================] - 1s 179us/step - loss: 0.3902 - accuracy: 0.8394
# Epoch 46/100
# 8000/8000 [==============================] - 2s 225us/step - loss: 0.3884 - accuracy: 0.8380
# Epoch 47/100
# 8000/8000 [==============================] - 2s 237us/step - loss: 0.3869 - accuracy: 0.8388
# Epoch 48/100
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.3852 - accuracy: 0.8382
# Epoch 49/100
# 8000/8000 [==============================] - 2s 231us/step - loss: 0.3821 - accuracy: 0.8379
# Epoch 50/100
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.3773 - accuracy: 0.8370
# Epoch 51/100
# 8000/8000 [==============================] - 2s 228us/step - loss: 0.3737 - accuracy: 0.8372
# Epoch 52/100
# 8000/8000 [==============================] - 2s 226us/step - loss: 0.3695 - accuracy: 0.8405
# Epoch 53/100
# 8000/8000 [==============================] - 2s 218us/step - loss: 0.3660 - accuracy: 0.8426
# Epoch 54/100
# 8000/8000 [==============================] - 2s 231us/step - loss: 0.3635 - accuracy: 0.8472
# Epoch 55/100
# 8000/8000 [==============================] - 2s 227us/step - loss: 0.3606 - accuracy: 0.8481
# Epoch 56/100
# 8000/8000 [==============================] - 2s 228us/step - loss: 0.3582 - accuracy: 0.8491
# Epoch 57/100
# 8000/8000 [==============================] - 2s 230us/step - loss: 0.3572 - accuracy: 0.8514
# Epoch 58/100
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.3557 - accuracy: 0.8536
# Epoch 59/100
# 8000/8000 [==============================] - 2s 244us/step - loss: 0.3549 - accuracy: 0.8551
# Epoch 60/100
# 8000/8000 [==============================] - 2s 230us/step - loss: 0.3534 - accuracy: 0.8576
# Epoch 61/100
# 8000/8000 [==============================] - 2s 226us/step - loss: 0.3526 - accuracy: 0.8587
# Epoch 62/100
# 8000/8000 [==============================] - 2s 234us/step - loss: 0.3514 - accuracy: 0.8579
# Epoch 63/100
# 8000/8000 [==============================] - 2s 225us/step - loss: 0.3504 - accuracy: 0.8579
# Epoch 64/100
# 8000/8000 [==============================] - 2s 219us/step - loss: 0.3496 - accuracy: 0.8591
# Epoch 65/100
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.3490 - accuracy: 0.8602
# Epoch 66/100
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.3480 - accuracy: 0.8600
# Epoch 67/100
# 8000/8000 [==============================] - 2s 220us/step - loss: 0.3473 - accuracy: 0.8612
# Epoch 68/100
# 8000/8000 [==============================] - 2s 234us/step - loss: 0.3468 - accuracy: 0.8587
# Epoch 69/100
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.3464 - accuracy: 0.8584
# Epoch 70/100
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.3452 - accuracy: 0.8599
# Epoch 71/100
# 8000/8000 [==============================] - 2s 233us/step - loss: 0.3443 - accuracy: 0.8596
# Epoch 72/100
# 8000/8000 [==============================] - 2s 225us/step - loss: 0.3444 - accuracy: 0.8606
# Epoch 73/100
# 8000/8000 [==============================] - 2s 228us/step - loss: 0.3436 - accuracy: 0.8577
# Epoch 74/100
# 8000/8000 [==============================] - 2s 231us/step - loss: 0.3434 - accuracy: 0.8608
# Epoch 75/100
# 8000/8000 [==============================] - 2s 227us/step - loss: 0.3434 - accuracy: 0.8616
# Epoch 76/100
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.3424 - accuracy: 0.8604
# Epoch 77/100
# 8000/8000 [==============================] - 2s 232us/step - loss: 0.3420 - accuracy: 0.8612
# Epoch 78/100
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.3413 - accuracy: 0.8599
# Epoch 79/100
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.3417 - accuracy: 0.8609
# Epoch 80/100
# 8000/8000 [==============================] - 2s 234us/step - loss: 0.3411 - accuracy: 0.8596
# Epoch 81/100
# 8000/8000 [==============================] - 3s 337us/step - loss: 0.3403 - accuracy: 0.8630
# Epoch 82/100
# 8000/8000 [==============================] - 2s 199us/step - loss: 0.3410 - accuracy: 0.8633
# Epoch 83/100
# 8000/8000 [==============================] - 2s 261us/step - loss: 0.3398 - accuracy: 0.8620
# Epoch 84/100
# 8000/8000 [==============================] - 2s 192us/step - loss: 0.3404 - accuracy: 0.8604
# Epoch 85/100
# 8000/8000 [==============================] - 2s 192us/step - loss: 0.3396 - accuracy: 0.8602
# Epoch 86/100
# 8000/8000 [==============================] - 1s 176us/step - loss: 0.3406 - accuracy: 0.8633
# Epoch 87/100
# 8000/8000 [==============================] - 1s 183us/step - loss: 0.3397 - accuracy: 0.8619
# Epoch 88/100
# 8000/8000 [==============================] - 1s 181us/step - loss: 0.3397 - accuracy: 0.8620
# Epoch 89/100
# 8000/8000 [==============================] - 1s 184us/step - loss: 0.3395 - accuracy: 0.8610
# Epoch 90/100
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.3391 - accuracy: 0.8620
# Epoch 91/100
# 8000/8000 [==============================] - 2s 259us/step - loss: 0.3379 - accuracy: 0.8612
# Epoch 92/100
# 8000/8000 [==============================] - 2s 286us/step - loss: 0.3391 - accuracy: 0.8599
# Epoch 93/100
# 8000/8000 [==============================] - 2s 312us/step - loss: 0.3380 - accuracy: 0.8625
# Epoch 94/100
# 8000/8000 [==============================] - 2s 275us/step - loss: 0.3387 - accuracy: 0.8611
# Epoch 95/100
# 8000/8000 [==============================] - 2s 266us/step - loss: 0.3385 - accuracy: 0.8616
# Epoch 96/100
# 8000/8000 [==============================] - 2s 290us/step - loss: 0.3389 - accuracy: 0.8619
# Epoch 97/100
# 8000/8000 [==============================] - 3s 319us/step - loss: 0.3382 - accuracy: 0.8590
# Epoch 98/100
# 8000/8000 [==============================] - 2s 250us/step - loss: 0.3388 - accuracy: 0.8593
# Epoch 99/100
# 8000/8000 [==============================] - 2s 257us/step - loss: 0.3386 - accuracy: 0.8610
# Epoch 100/100
# 8000/8000 [==============================] - 2s 263us/step - loss: 0.3377 - accuracy: 0.8601

# %% [markdown]
# ### Part - 3 : Making the predictions and evaluating model

# %%
# Predicting the test set results
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([[0.34351107],
#        [0.26100188],
#        [0.10298583],
#        ...,
#        [0.17989859],
#        [0.19273156],
#        [0.19069606]], dtype=float32)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d6b90b5d4385> in <module>
#       1 # Making the Confusion Matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 cm = confusion_matrix(y_test, y_pred)
#       4 cm
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
